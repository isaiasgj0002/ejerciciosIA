# %% [markdown]
# <a href="https://colab.research.google.com/github/isaiasgj0002/ejerciciosIA/blob/main/Algoritmos%20Python/tareas/RegresionLinealSimpleEjemplo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Algoritmo que predice el precio de una vivienda usando la regresion lineal simple**
# ![rls.JPG](data:image/jpeg;base64,...)<br>
# Este Algoritmo recibe un conjunto de datos que nos proporciona la libreria skleanr, con el objetivo de que pueda predecir el precio de una vivienda usando el metodo de regresion lineal simple, los resultados se grafican en graficos usando la libreria **MATPLOTLIB**
#
# **Estudiante: Isaias Guzmán Jordán<br>
# Semestre: 4<br>
# Curso: Algoritmia para la inteligencia artificial**

# %%
import numpy as np
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)

# %%
datos = datasets.load_boston()
print(datos)
print("Informacion en el dataset: ")
print(datos.keys())
print("Caracteristicas del dataset")
print(datos.DESCR)
print("Cantidad de datos: ")
print(datos.data.shape)
print("Nombre columnas: ")
print(datos.feature_names)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
x = datos.data[:, np.newaxis, 5]
y = datos.target

# %%
plt.scatter(x,y)
plt.xlabel("Numero de habitaciones")
plt.ylabel("valor medio")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)
lr = linear_model.LinearRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, y_pred, color='red',linewidth=3)
plt.title('Regresion lineal simple')
plt.xlabel('Numero de habitaciones')
plt.ylabel('valor medio')
plt.show()

# %%
print("Datos del modelo de regresion lineal simple")
print("valor de la pendiente o coeficiente a: ")
print(lr.coef_)
print("valor de la interseccion o coeficiente b: ")
print(lr.intercept_)
print("la ecuacion de el modelo de regresion lineal simple es: ")
print('y=',lr.coef_,'x=',lr.intercept_)
print("Precision del modelo")
print(lr.score(x_train, y_train))
# Out:
# Datos del modelo de regresion lineal simple
# valor de la pendiente o coeficiente a:
# [8.82731694]
# valor de la interseccion o coeficiente b:
# -33.00882223117998
# la ecuacion de el modelo de regresion lineal simple es:
# y= [8.82731694] x= -33.00882223117998
# Precision del modelo
# 0.45724076431735516

# %%
#ISAIAS GUZMÁN JORDÁN
#SENATI 4TO SEMESTRE
#ALGORITMIA PARA LA INTELIGENCIA ARTIFICIAL
